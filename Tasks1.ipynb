# %%
import pandas as pd

# %%
df=pd.read_csv("GlobalWeatherRepository.csv")
df

# %% [markdown]
# Inspect dataset structure, data types, and key variables.

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  16-05-2024 13:15                 26.6
# 1          1715849100  16-05-2024 10:45                 19.0
# 2          1715849100  16-05-2024 09:45                 23.0
# 3          1715849100  16-05-2024 10:45                  6.3
# 4          1715849100  16-05-2024 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# 1                    66.2  Partly cloudy  ...                1.1
# 2                    73.4          Sunny  ...               10.4
# 3                    43.3  Light drizzle  ...                0.7
# 4                    78.8  Partly cloudy  ...              183.4
#
#    air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0              26.6                         1                          1
# 1               2.0                         1                          1
# 2              18.4                         1                          1
# 3               0.9                         1                          1
# 4             262.3                         5                         10
#
#    sunrise   sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  4:50 AM  6:50 PM  12:12 PM   1:11 AM  Waxing Gibbous                 55
# 1  5:21 AM  7:54 PM  12:58 PM   2:14 AM  Waxing Gibbous                 55
# 2  5:40 AM  7:50 PM   1:15 PM   2:14 AM  Waxing Gibbous                 55
# 3  6:31 AM  9:11 PM   2:12 PM   3:31 AM  Waxing Gibbous                 55
# 4  6:12 AM  5:55 PM   1:17 PM  12:38 AM  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 106983  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 106984    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 106985      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 106986     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 106987   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 106983          1763363700  17-11-2025 03:15                 25.2
# 106984          1763363700  17-11-2025 14:15                 26.3
# 106985          1763363700  17-11-2025 10:15                 17.1
# 106986          1763363700  17-11-2025 09:15                 20.1
# 106987          1763363700  17-11-2025 09:15                 17.9
#
#         temperature_fahrenheit      condition_text  ...  air_quality_PM2.5  \
# 106983                    77.4       Partly cloudy  ...               6.75
# 106984                    79.3  Patchy rain nearby  ...              66.05
# 106985                    62.8               Sunny  ...               8.05
# 106986                    68.2  Patchy rain nearby  ...              15.65
# 106987                    64.2   Light rain shower  ...              30.75
#
#         air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 106983              6.85                         1                          1
# 106984             66.05                         4                          9
# 106985             25.05                         1                          1
# 106986             15.75                         2                          2
# 106987             31.05                         2                          3
#
#         sunrise   sunset  moonrise  moonset       moon_phase  \
# 106983  6:24 AM  6:02 PM   4:12 AM  4:11 PM  Waning Crescent
# 106984  6:08 AM  5:15 PM   3:27 AM  3:12 PM  Waning Crescent
# 106985  6:06 AM  5:30 PM   3:38 AM  3:31 PM  Waning Crescent
# 106986  5:27 AM  6:17 PM   3:20 AM  4:06 PM  Waning Crescent
# 106987  5:12 AM  6:10 PM   3:06 AM  3:57 PM  Waning Crescent
#
#         moon_illumination
# 106983                  9
# 106984                 11
# 106985                 10
# 106986                 10
# 106987                 10
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (106988, 41)

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                  int64
# uv_index                        float64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                          object
# sunset                           object
# moonrise                         object
# moonset                          object
# moon_phase                       object
# moon_illumination                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106988 entries, 0 to 106987
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       106988 non-null  object
#  1   location_name                 106988 non-null  object
#  2   latitude                      106988 non-null  float64
#  3   longitude                     106988 non-null  float64
#  4   timezone                      106988 non-null  object
#  5   last_updated_epoch            106988 non-null  int64
#  6   last_updated                  106988 non-null  object
#  7   temperature_celsius           106988 non-null  float64
#  8   temperature_fahrenheit        106988 non-null  float64
#  9   condition_text                106988 non-null  object
#  10  wind_mph                      106988 non-null  float64
#  11  wind_kph                      106988 non-null  float64
#  12  wind_degree                   106988 non-null  int64
#  13  wind_direction                106988 non-null  object
#  14  pressure_mb                   106988 non-null  int64
#  15  pressure_in                   106988 non-null  float64
#  16  precip_mm                     106988 non-null  float64
#  17  precip_in                     106988 non-null  float64
#  18  humidity                      106988 non-null  int64
#  19  cloud                         106988 non-null  int64
#  20  feels_like_celsius            106988 non-null  float64
#  21  feels_like_fahrenheit         106988 non-null  float64
#  22  visibility_km                 106988 non-null  float64
#  23  visibility_miles              106988 non-null  int64
#  24  uv_index                      106988 non-null  float64
#  25  gust_mph                      106988 non-null  float64
#  26  gust_kph                      106988 non-null  float64
#  27  air_quality_Carbon_Monoxide   106988 non-null  float64
#  28  air_quality_Ozone             106988 non-null  float64
#  29  air_quality_Nitrogen_dioxide  106988 non-null  float64
#  30  air_quality_Sulphur_dioxide   106988 non-null  float64
#  31  air_quality_PM2.5             106988 non-null  float64
#  32  air_quality_PM10              106988 non-null  float64
#  33  air_quality_us-epa-index      106988 non-null  int64
#  34  air_quality_gb-defra-index    106988 non-null  int64
#  35  sunrise                       106988 non-null  object
#  36  sunset                        106988 non-null  object
#  37  moonrise                      106988 non-null  object
#  38  moonset                       106988 non-null  object
#  39  moon_phase                    106988 non-null  object
#  40  moon_illumination             106988 non-null  int64
# dtypes: float64(21), int64(9), object(11)
# memory usage: 33.5+ MB

# %%
for col in df.select_dtypes(include='object').columns:
    print("Unique_Values",col, ":", df[col].nunique())
# Out:
# Unique_Values country : 211
# Unique_Values location_name : 254
# Unique_Values timezone : 197
# Unique_Values last_updated : 18497
# Unique_Values condition_text : 47
# Unique_Values wind_direction : 16
# Unique_Values sunrise : 461
# Unique_Values sunset : 544
# Unique_Values moonrise : 1441
# Unique_Values moonset : 1441
# Unique_Values moon_phase : 8

# %%
for col in df.select_dtypes(include='float').columns:
    print("Unique_Values",col, ":", df[col].nunique())
# Out:
# Unique_Values latitude : 394
# Unique_Values longitude : 399
# Unique_Values temperature_celsius : 655
# Unique_Values temperature_fahrenheit : 1081
# Unique_Values wind_mph : 180
# Unique_Values wind_kph : 180
# Unique_Values pressure_in : 207
# Unique_Values precip_mm : 618
# Unique_Values precip_in : 74
# Unique_Values feels_like_celsius : 769
# Unique_Values feels_like_fahrenheit : 1303
# Unique_Values visibility_km : 70
# Unique_Values uv_index : 163
# Unique_Values gust_mph : 499
# Unique_Values gust_kph : 758
# Unique_Values air_quality_Carbon_Monoxide : 5259
# Unique_Values air_quality_Ozone : 635
# Unique_Values air_quality_Nitrogen_dioxide : 2563
# Unique_Values air_quality_Sulphur_dioxide : 2421
# Unique_Values air_quality_PM2.5 : 4542
# Unique_Values air_quality_PM10 : 6502

# %%
for col in df.select_dtypes(include='int').columns:
    print("Unique_Values", col , ":", df[col].nunique())
# Out:
# Unique_Values last_updated_epoch : 1064
# Unique_Values wind_degree : 360
# Unique_Values pressure_mb : 89
# Unique_Values humidity : 99
# Unique_Values cloud : 101
# Unique_Values visibility_miles : 13
# Unique_Values air_quality_us-epa-index : 6
# Unique_Values air_quality_gb-defra-index : 10
# Unique_Values moon_illumination : 101
